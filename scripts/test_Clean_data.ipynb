# %%
pip install great-expectations
# Out:
# Collecting great-expectations
#   Using cached great_expectations-1.2.4-py3-none-any.whl (5.0 MB)
# Requirement already satisfied: pyparsing>=2.4 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (3.0.4)
# Requirement already satisfied: jsonschema>=2.5.1 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (3.2.0)
# Collecting pydantic>=1.10.7
#   Using cached pydantic-2.10.1-py3-none-any.whl (455 kB)
# Requirement already satisfied: tqdm>=4.59.0 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (4.66.5)
# Collecting ruamel.yaml>=0.16
#   Using cached ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
# Requirement already satisfied: mistune>=0.8.4 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (0.8.4)
# Requirement already satisfied: requests>=2.20 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (4.12.2)
# Requirement already satisfied: jinja2>=2.10 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (2.11.3)
# Collecting marshmallow<4.0.0,>=3.7.1
#   Using cached marshmallow-3.23.1-py3-none-any.whl (49 kB)
# Collecting altair<5.0.0,>=4.2.1
#   Using cached altair-4.2.2-py3-none-any.whl (813 kB)
# Collecting posthog<3,>=2.1.0
#   Using cached posthog-2.5.0-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: packaging in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (21.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (1.7.1)
# Requirement already satisfied: pandas<2.2,>=1.1.3 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (1.3.4)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (2.8.2)
# Requirement already satisfied: cryptography>=3.2 in c:\users\auka\anaconda3\lib\site-packages (from great-expectations) (3.4.8)
# Collecting tzlocal>=1.2
#   Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: entrypoints in c:\users\auka\anaconda3\lib\site-packages (from altair<5.0.0,>=4.2.1->great-expectations) (0.3)
# Requirement already satisfied: toolz in c:\users\auka\anaconda3\lib\site-packages (from altair<5.0.0,>=4.2.1->great-expectations) (0.11.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\auka\anaconda3\lib\site-packages (from cryptography>=3.2->great-expectations) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\auka\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2->great-expectations) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\auka\anaconda3\lib\site-packages (from jinja2>=2.10->great-expectations) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\auka\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great-expectations) (58.0.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\auka\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great-expectations) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\auka\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great-expectations) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\auka\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great-expectations) (0.18.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\auka\anaconda3\lib\site-packages (from pandas<2.2,>=1.1.3->great-expectations) (2021.3)
# Collecting monotonic>=1.5
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting pydantic-core==2.27.1
#   Using cached pydantic_core-2.27.1-cp39-none-win_amd64.whl (2.0 MB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\auka\anaconda3\lib\site-packages (from requests>=2.20->great-expectations) (1.26.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\auka\anaconda3\lib\site-packages (from requests>=2.20->great-expectations) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\auka\anaconda3\lib\site-packages (from requests>=2.20->great-expectations) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\auka\anaconda3\lib\site-packages (from requests>=2.20->great-expectations) (2021.10.8)
# Collecting ruamel.yaml.clib>=0.2.7
#   Using cached ruamel.yaml.clib-0.2.12-cp39-cp39-win_amd64.whl (118 kB)
# Requirement already satisfied: colorama in c:\users\auka\anaconda3\lib\site-packages (from tqdm>=4.59.0->great-expectations) (0.4.4)
# Collecting tzdata
#   Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: tzdata, ruamel.yaml.clib, pydantic-core, monotonic, backoff, annotated-types, tzlocal, ruamel.yaml, pydantic, posthog, marshmallow, altair, great-expectations
# Successfully installed altair-4.2.2 annotated-types-0.7.0 backoff-2.2.1 great-expectations-1.2.4 marshmallow-3.23.1 monotonic-1.6 posthog-2.5.0 pydantic-2.10.1 pydantic-core-2.27.1 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.12 tzdata-2024.2 tzlocal-5.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (c:\users\auka\anaconda3\lib\site-packages)

# %%
from great_expectations.dataset import PandasDataset
import pandas as pd

# Loading the actual dataset
actual_data = PandasDataset(pd.read_csv("Clean_data.csv"))

# Basic Expectations
def test_actual_data_integrity():
    # Checking existence and null values for key columns
    assert actual_data.expect_column_to_exist("sideb").success
    assert actual_data.expect_column_to_exist("sidea").success
    assert actual_data.expect_column_values_to_not_be_null("country_primary").success
    assert actual_data.expect_column_values_to_not_be_null("NSAdyad_id").success

# Schema Validation
def test_actual_data_schema():
    schema = {
        "sideb": "string",
        "sideb_full": "string",
        "country_primary": "string",
        "sidea": "string",
        "sideb_id": "int",
        "NSAdyad_id": "int",
        "frontline_prev_best": "float",
        "frontline": "float",
        "lead": "float"
    }
    for col, dtype in schema.items():
        assert actual_data.expect_column_values_to_be_of_type(col, dtype).success

# Relationship Checks
def test_actual_data_relationships():
    # Example: frontline must always be greater than or equal to frontline_prev_best
    assert actual_data.expect_column_pair_values_a_to_be_greater_than_or_equal_to_b(
        "frontline", "frontline_prev_best"
    ).success

    # Example: lead values should be greater than zero
    assert actual_data.expect_column_values_to_be_greater_than(
        "lead", 0
    ).success

    # Example: Check correlation between columns, if applicable
    assert actual_data.expect_column_pair_values_to_be_in_set(
        "sideb", "sidea"
    ).success

if __name__ == "__main__":
    test_actual_data_integrity()
    test_actual_data_schema()
    test_actual_data_relationships()

    print("All tests passed successfully!")
